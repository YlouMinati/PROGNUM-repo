# %% [markdown]
# ![dog-relax.gif](attachment:dog-relax.gif)

# %% [markdown]
# . current directory (does basicaly nothing)
#
# .. the parent directory (the directory you had open before)

# %% [markdown]
# cd ~/Desktop

# %% [markdown]
# Describe the results of the command: ls *[0-9]*.[co].
#  shows all files with a number between 0 and 9 and either a c,o or both.
#
# What is the meaning of the square brackets [ and ]?
# And explain the difference between this command and ls *[0-9]*.co
# with the brackets it can be either any in between or one or the other (depends if there is a - ) if there are no brackets only the files with co wil be selected.
