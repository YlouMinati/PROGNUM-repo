# %% [markdown]
# * Name: Ylou Mesu
# * Username: ymmesu
# * Student s-number: S6358179
# * Group (AS1, etc.): AS3

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# ![rick-astley.png](attachment:rick-astley.png)

# %%
x=6
x*=5
x*=4
x*=3
x*=2
x*=1 
print(x)
# Out:
# 720

# %%
import scipy.constants

from scipy.constants import h
from scipy.constants import c

x= h*(2.42e28)

print(x)
# Out:
# 1.6035089763e-05

# %%
mass_moon=7.342e22
mass_sun=5.9722e24
d_me=385000600

import scipy.constants

from scipy.constants import G

x=(G*mass_moon*mass_sun)/(d_me**2)

print(x)
# Out:
# 1.974384051807571e+20

# %%
from scipy.constants import G, pi

from scipy.constants import year as p
au= 149597871000
mt_sun= 4*(pi**2)*(au**3)/((p**2)*G)
print(mt_sun)
# Out:
# 1.991209877460257e+30

# %%
x1 = 10
x2 = 22/7
print(x1, end="\n\n")
print(x2, end="")
# Out:
# 10
#
# 3.142857142857143

# %% [markdown]
# defines how the output will end (put in between the "")
